# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Generic Error**

# %%
try:
    with open("C:\\Users\\Pradhumn\\OneDrive\\Documents\\text.txt", "r") as f:
        print(f.read())
except:
    print("file not found")
# Out:
# Jai Shree Ram

# %% [markdown]
# ### **Specific Error**

# %%
try:
    with open("C:\\sers\\Pradhumn\\OneDrive\\Documents\\text.txt", "r") as f:
        print(f.read())
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'C:\\sers\\Pradhumn\\OneDrive\\Documents\\text.txt'

# %%
try:
    with open("C:\\Users\\Pradhumn\\OneDrive\\Documents\\text.txt", "r") as f:
        print(f.read())
        print(m)
except FileNotFoundError:
    print("File not found")
except NameError:
    print("Variable not defined")
# Out:
# Jai Shree Ram
# Variable not defined

# %% [markdown]
# ### **Else**

# %%
try:
    f = open("C:\\Users\\Pradhumn\\OneDrive\\Documents\\text.txt", "r")
except FileNotFoundError:
    print("File not found")
else:
    print("File read successfully")
# Out:
# File read successfully

# %%
try:
    f = open("C:\\Users\\Pradhumn\\OneDrive\\Documents\\text.txt", "r")
    print(f.read())
except FileNotFoundError:
    print("File not found")
# Out:
# Jai Shree Ram

# %% [markdown]
# ### **Finally**

# %%
try:
    f = open("C:\\Users\\Pradhumn\\OneDrive\\Documents\\text.txt", "r")
    print(f.read())
except FileNotFoundError:
    print("File not found")
else:
    print("File read successfully")
    
finally:
    print("Execution completed")
# Out:
# Jai Shree Ram
# File read successfully
# Execution completed

# %% [markdown]
# ### **raise**

# %%
raise NameError("Aise hi try kr rha hoon")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 raise NameError("Aise hi try kr rha hoon")
#
# NameError: Aise hi try kr rha hoon
