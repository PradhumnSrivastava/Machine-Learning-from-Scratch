# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
    with open("C:\\Users\\Pradhumn\\OneDrive\\Documents\\text.txt", "r") as f:
        print(f.read())
except:
    print("file not found")
# Out:
# Jai Shree Ram
